# %% [markdown]
# # Simple linear regression
#
# Simple linear regression aims to find a linear relationship to describe the correlation between a single independent and possibly dependent variable. The regression line can be used to predict or estimate missing values, this is known as interpolation.
#
# ### Least Squares Regression Line, LSRL
#
# The calculation is based on the method of least squares. The idea behind it is to minimise the sum of the vertical distance between all of the data points and the line of best fit.
#
# Consider these attempts at drawing the line of best fit, they all look like they could be a fair line of best fit, but in fact Diagram 3 is the most accurate as the regression line has been calculated using the least squares regression line.
#
# ![lr.png](attachment:lr.png)
#
# The equation of the least squares regression line is
#
# **ŷ= b + mx**
#
# where:
#
# **ŷ is the predicted value of y**

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'G:\course\Youtobe ML\ML Algorithm mathematical and geometric intuition\Linear Regression\Simple_Linear_Regression\placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
y.head()
# Out:
# 0    3.26
# 1    1.98
# 2    3.25
# 3    3.67
# 4    3.57
# Name: package, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %% [markdown]
# ## Creating Simple Linear Regression Algorithm with code

# %%
class MYLR:
    def __init__(self):
        self.m=None
        self.b=None
        
    def fit(self,X_train,y_train):
        n=0 # NUMERATOR
        d=0 # DENOMINATOR
        for i in range(X_train.shape[0]):
            
            n = n + ((X_train[i]-X_train.mean())*(y_train[i]-y_train.mean()))
            d = d + ((X_train[i]-X_train.mean())*(X_train[i]-X_train.mean()))
        
        self.m = n/d
        self.b = y_train.mean() - (self.m * X_train.mean())
        print("intercept_ :",self.b)
        print("coef_ :",self.m)
        
    def predict(self,X_test):
        return self.m * X_test + self.b

# %%
mylr = MYLR()
mylr.fit(X_train,y_train)
y_pred1 = mylr.predict(X_test)

# %%
print("intercept_ :",self.b)
print("coef_ :",self.m)
# Out:
# intercept_ : -0.9998951779221401
# coef_ : [0.57111357]

# %% [markdown]
# ## Simple_Linear_Regression from Sklearn library

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.78658779])

# %%
b = lr.intercept_
m = lr.coef_

# %%
print("intercept_ :",b)
print("coef_ :",m)
# Out:
# intercept_ : -0.9998951779221401
# coef_ : [0.57111357]

# %% [markdown]
# #### Both the values are the same

# %% [markdown]
# ## Plotting both regression line graphs

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.plot(X_train,mylr.predict(X_train),color='black')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
# y = mx + b

m * 8.58 + b
# Out:
# array([3.90025926])

# %%
m * 9.5 + b
# Out:
# array([4.42568374])

# %%
m * 100 + b
# Out:
# array([56.11146188])
